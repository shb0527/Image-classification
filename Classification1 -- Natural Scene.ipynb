# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
generator = ImageDataGenerator(rescale=1./255, validation_split = 0.2)


directory_train =  '../Suhyun/ar2/seg_train/seg_train'
# train_generator = generator.flow_from_directory(
#      directory_train,
#     target_size = (224,224),
#     batch_size = 10)

directory_test = '../Suhyun/ar2/seg_test/seg_test'
train_dataset = generator.flow_from_directory(batch_size=32,
                                                 directory = directory_train,
                                                 shuffle=True,
                                                 target_size=(224, 224), 
                                                 subset="training",
                                                 class_mode='categorical')

validation_dataset = generator.flow_from_directory(batch_size=32,
                                                 directory = directory_train,
                                                 shuffle=True,
                                                 target_size=(224, 224), 
                                                 subset="validation",

                                                 class_mode='categorical')
# Out:
# Found 11230 images belonging to 6 classes.
# Found 2804 images belonging to 6 classes.

# %%
import matplotlib.pyplot as plt
fig,ax = plt.subplots(nrows=1,ncols=10,figsize=(20,20))
for i in range(10):
    ax[i].imshow(train_dataset[0][0][i])
    ax[i].axis('off')

# %%
def hard_swish(features):

  
  features = tf.convert_to_tensor(features)
  fdtype = features.dtype
  return features * tf.nn.relu6(features + tf.cast(3., fdtype)) * (1. / 6.)

# %%
def se_block(inputs, ch, ratio=16):

    x = tf.keras.layers.GlobalAveragePooling2D()(inputs)
    x = tf.keras.layers.Dense(ch//ratio, activation='relu')(x)
    y = tf.keras.layers.Dense(ch, activation='sigmoid')(x)
    y = tf.keras.layers.multiply([inputs, y])
    out = hard_swish(y)
    return out

# %%
def dep_bn(inputs, filter : int, kernel :int, stride: int):

  y = tf.keras.layers.Conv2D(filters = filter, kernel_size= kernel, strides= stride, padding= 'same')(inputs)
  bn = tf.keras.layers.BatchNormalization(axis = 1)(y)
  out = tf.nn.relu6(bn)
  
  return out


def Inverted_residual_SEblock(x,  hs: bool, se: bool , filters, kernel, strides,  expansion_ratio ):


    #pointwise
    y = tf.keras.layers.Conv2D(filters = x.get_shape().as_list()[-1]*expansion_ratio, kernel_size=  1, strides = 1, padding= 'same')(x)
    bn = tf.keras.layers.BatchNormalization(axis = 1)(y)
    if hs:
        y_p = hard_swish(bn)
    else:
        y_p = tf.nn.relu6(bn)
    
    
    #depthwise
    y = tf.keras.layers.DepthwiseConv2D(kernel_size=  kernel, strides= strides, padding= 'same', depth_multiplier = 1)(y_p)
    bn = tf.keras.layers.BatchNormalization(axis = 1)(y)
    if hs:
        out = hard_swish(bn)
    else:
        out = tf.nn.relu6(bn)
   
    
    if se: 
        channel = out.get_shape().as_list()[-1]
        out = se_block(out, channel)

    
    #pointwise
    y = tf.keras.layers.Conv2D(filters = filters, kernel_size=  1, strides = 1, padding= 'same')(out)
    bn = tf.keras.layers.BatchNormalization(axis = 1)(y)
    if hs:
        y_p = hard_swish(bn)
    else:
        y_p = tf.nn.relu6(bn)
        
        
    
    if strides == 1:
        if x.shape[3] != filters : 
           x = tf.keras.layers.Conv2D(filters = filters, kernel_size = 1, strides = strides, padding = "same")(x)
        out  = tf.keras.layers.Add()([x, y_p])
   
    

    return y

# %%
def create_mobilenetV3(inputs):

   x = dep_bn(inputs, 16, 3, 2)
   x = Inverted_residual_SEblock(x, False, False, 16, 3, 1,1)

   x = Inverted_residual_SEblock(x, False, False, 24, 3, 2, 4)
   x = Inverted_residual_SEblock(x, False, False, 24, 3, 1, 3)
   
   x = Inverted_residual_SEblock(x, False, True, 40, 5, 2, 3)
   x = Inverted_residual_SEblock(x, False, True, 40, 5, 1, 3)
   x = Inverted_residual_SEblock(x, False, True, 40, 5, 1, 3)

   x = Inverted_residual_SEblock(x, True, False, 80, 3, 2, 6)
   x = Inverted_residual_SEblock(x, True, False, 80, 3, 1, 2.5)
   x = Inverted_residual_SEblock(x, True, False, 80, 3, 1, 184/80)
   x = Inverted_residual_SEblock(x, True, False, 80, 3, 1, 184/80)
    
   x = Inverted_residual_SEblock(x, True, True, 112, 3, 1, 6)
   x = Inverted_residual_SEblock(x, True, True, 112, 3, 1, 6)
    
   x = Inverted_residual_SEblock(x, True, True, 160, 5, 2, 6)
   
   x = Inverted_residual_SEblock(x, True, True, 160, 5, 1, 6)
   x = Inverted_residual_SEblock(x, True, True, 160, 5, 1, 6)
   x = dep_bn(x, 960, 1, 1)
   
   t = tf.keras.layers.AveragePooling2D(1)(x)
   t = tf.keras.layers.Flatten()(t)
   outputs = tf.keras.layers.Dense(6, activation='softmax')(t)
   return outputs

# %%
# model = tf.keras.applications.MobileNetV3Large()

# %%
# instantiating the model in the strategy scope creates the model on the TPU
with tpu_strategy.scope():
    inputs = tf.keras.Input(shape=(224,224,3))
    outputs = create_mobilenetV3(inputs)

    model = tf.keras.Model(inputs, outputs)

    opt = tf.keras.optimizers.Adam(learning_rate=0.001)
    model.compile(
        optimizer=opt,
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    model.fit(train_dataset, validation_data=validation_dataset, epochs = 1)

# %%
inputs = tf.keras.Input(shape=(224,224,3))
outputs = create_mobilenetV3(inputs)

model = tf.keras.Model(inputs, outputs)

opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(
        optimizer=opt,
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

# %%
model.fit(train_dataset, validation_data=validation_dataset, epochs = 100)
# Out:
# Epoch 1/100
# 351/351 [==============================] - 38s 94ms/step - loss: 1.7331 - accuracy: 0.3561 - val_loss: 2.2056 - val_accuracy: 0.1619
# Epoch 2/100
# 351/351 [==============================] - 32s 91ms/step - loss: 1.1805 - accuracy: 0.5304 - val_loss: 1.0823 - val_accuracy: 0.5877
# Epoch 3/100
# 351/351 [==============================] - 32s 92ms/step - loss: 1.0227 - accuracy: 0.5874 - val_loss: 2.6593 - val_accuracy: 0.4173
# Epoch 4/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.9168 - accuracy: 0.6313 - val_loss: 0.9247 - val_accuracy: 0.6444
# Epoch 5/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.8341 - accuracy: 0.6777 - val_loss: 1.8406 - val_accuracy: 0.4825
# Epoch 6/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.7716 - accuracy: 0.7104 - val_loss: 1.4387 - val_accuracy: 0.6213
# Epoch 7/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.7352 - accuracy: 0.7208 - val_loss: 1.7858 - val_accuracy: 0.4911
# Epoch 8/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.6958 - accuracy: 0.7400 - val_loss: 0.7890 - val_accuracy: 0.7065
# Epoch 9/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.6789 - accuracy: 0.7438 - val_loss: 0.8758 - val_accuracy: 0.6694
# Epoch 10/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.6282 - accuracy: 0.7658 - val_loss: 0.6880 - val_accuracy: 0.7447
# Epoch 11/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.6341 - accuracy: 0.7620 - val_loss: 0.8318 - val_accuracy: 0.6876
# Epoch 12/100
# 351/351 [==============================] - 32s 91ms/step - loss: 0.5999 - accuracy: 0.7796 - val_loss: 0.8131 - val_accuracy: 0.7101
# Epoch 13/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.5906 - accuracy: 0.7826 - val_loss: 1.0940 - val_accuracy: 0.6715
# Epoch 14/100
# 351/351 [==============================] - 33s 93ms/step - loss: 0.5696 - accuracy: 0.7890 - val_loss: 0.6999 - val_accuracy: 0.7471
# Epoch 15/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.5712 - accuracy: 0.7923 - val_loss: 0.8355 - val_accuracy: 0.6994
# Epoch 16/100
# 351/351 [==============================] - 32s 93ms/step - loss: 0.5473 - accuracy: 0.7973 - val_loss: 0.7764 - val_accuracy: 0.7389
# Epoch 17/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.5436 - accuracy: 0.8035 - val_loss: 0.5883 - val_accuracy: 0.7889
# Epoch 18/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.5238 - accuracy: 0.8083 - val_loss: 0.5823 - val_accuracy: 0.7860
# Epoch 19/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.5088 - accuracy: 0.8141 - val_loss: 0.9932 - val_accuracy: 0.6534
# Epoch 20/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.5071 - accuracy: 0.8156 - val_loss: 1.0234 - val_accuracy: 0.6990
# Epoch 21/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.
100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.1666 - accuracy: 0.9370 - val_loss: 0.7546 - val_accuracy: 0.8174
# Epoch 82/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.1561 - accuracy: 0.9447 - val_loss: 1.1519 - val_accuracy: 0.7307
# Epoch 83/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.1681 - accuracy: 0.9395 - val_loss: 0.7093 - val_accuracy: 0.8049
# Epoch 84/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.1617 - accuracy: 0.9395 - val_loss: 0.6927 - val_accuracy: 0.8106
# Epoch 85/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.1587 - accuracy: 0.9407 - val_loss: 0.6856 - val_accuracy: 0.8210
# Epoch 86/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.1774 - accuracy: 0.9358 - val_loss: 0.7084 - val_accuracy: 0.8270
# Epoch 87/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.1556 - accuracy: 0.9423 - val_loss: 0.7862 - val_accuracy: 0.8063
# Epoch 88/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.1474 - accuracy: 0.9467 - val_loss: 0.7942 - val_accuracy: 0.8124
# Epoch 89/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.1427 - accuracy: 0.9472 - val_loss: 0.8553 - val_accuracy: 0.8071
# Epoch 90/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.1354 - accuracy: 0.9510 - val_loss: 0.8799 - val_accuracy: 0.7971
# Epoch 91/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.1435 - accuracy: 0.9461 - val_loss: 1.1017 - val_accuracy: 0.7571
# Epoch 92/100
# 351/351 [==============================] - 32s 91ms/step - loss: 0.1389 - accuracy: 0.9471 - val_loss: 0.7259 - val_accuracy: 0.8185
# Epoch 93/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.1435 - accuracy: 0.9461 - val_loss: 0.8886 - val_accuracy: 0.7914
# Epoch 94/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.1321 - accuracy: 0.9514 - val_loss: 0.7239 - val_accuracy: 0.8220
# Epoch 95/100
# 351/351 [==============================] - 32s 91ms/step - loss: 0.1321 - accuracy: 0.9513 - val_loss: 0.7790 - val_accuracy: 0.8156
# Epoch 96/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.1292 - accuracy: 0.9536 - val_loss: 0.7557 - val_accuracy: 0.8185
# Epoch 97/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.1302 - accuracy: 0.9525 - val_loss: 0.7970 - val_accuracy: 0.8135
# Epoch 98/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.1293 - accuracy: 0.9522 - val_loss: 0.7934 - val_accuracy: 0.8156
# Epoch 99/100
# 351/351 [==============================] - 32s 91ms/step - loss: 0.1344 - accuracy: 0.9516 - val_loss: 0.8048 - val_accuracy: 0.8131
# Epoch 100/100
# 351/351 [==============================] - 32s 92ms/step - loss: 0.1331 - accuracy: 0.9528 - val_loss: 0.9250 - val_accuracy: 0.7810

# %%
predictions = model.predict(train_dataset[0][0])
def index_output(prediction) :
    
    index_list = []
    for pred in prediction:
        i = np.argmax(pred)
        index_list.append(i)
    return index_list
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-2-c7fbce50f308> in <module>
# ----> 1 predictions = model.predict(train_dataset[0][0])
#       2 def index_output(prediction) :
#       3
#       4     index_list = []
#       5     for pred in prediction:
#
# NameError: name 'model' is not defined

# %%
import numpy as np
y_pred = np.array(index_output(predictions))

# %%
y_pred.shape
# Out:
# (32,)

# %%
Y_true =[]
for y in validation_dataset[0][1]:
    Y_true.append(np.where(y==1))
Y_true = np.squeeze(np.asarray(Y_true))
Y_true.shape
# Out:
# (32,)

# %%
y_true = validation_dataset[0][1]
from sklearn.metrics import classification_report

print(classification_report(Y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       1.00      1.00      1.00         2
#            2       0.60      0.60      0.60         5
#            3       0.33      0.67      0.44         3
#            4       0.83      0.62      0.71         8
#            5       1.00      0.86      0.92         7
#
#     accuracy                           0.78        32
#    macro avg       0.79      0.79      0.78        32
# weighted avg       0.83      0.78      0.80        32
